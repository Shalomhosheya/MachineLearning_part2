# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split as ts

data = {
    "X": [1, 2, 3, 4, 5],
    "y": [2, 4, 6, 7, 10]
} 

df = pd.DataFrame(data)
X = df[['X']]
y = df['y']


model = LinearRegression()
model.fit(X,y)

print('\n',model.coef_[0])
print('\n',model.intercept_)

p = model.predict([[7]])
p
# Out:
#  1.9000000000000004
#
#  0.09999999999999876
# C:\Users\shalom hosheya\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.4])

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split as ts
import matplotlib.pyplot as plt
import seaborn as sns

pf = pd.read_csv('advertising.csv')
pf.head()

x = pf[['TV']]
y = pf[['Sales']]

x_train , x_test , y_train ,y_test = ts(x,y,test_size=0.2,random_state=42)#don't understand teach me

x_train.shape
x_test.shape
model = LinearRegression()
model.fit(x_train,y_train)

print('\n',model.coef_[0])
print('\n',model.intercept_)

pred=model.predict([[114]])
print(pred)
 
plt.figure(figsize=(8, 6))
plt.scatter(x_test, y_test, color='blue', label='Actual Sales')
plt.plot(x_test, model.predict(x_test), color='red', linewidth=2, label='Predicted Sales (Regression Line)')
plt.title('TV Ad Spending vs. Sales (Test Set)')
plt.xlabel('TV Ad Spending ($ thousands)')
plt.ylabel('Sales (thousands of units)')
plt.legend()
plt.show()
# Out:
#  [0.05548294]
#
#  [7.00710843]
# [[13.33216404]]
# C:\Users\shalom hosheya\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
